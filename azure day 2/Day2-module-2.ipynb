# %% [markdown]
# # welcome to day 2 module 2 of devops in Azure with me
#
# ### this are few work items in AZURE SCRUM BOARD

# %% [markdown]
# ![282837654-4600d0ae-031b-44d2-bbae-58de5abc8620.png](attachment:282837654-4600d0ae-031b-44d2-bbae-58de5abc8620.png)

# %% [markdown]
# #### Build a Project
# now to see and explore the scrum board on Azure , we will need dataset , a project , some work info and etc to visualize stuff, for this we will use AzureDemoGenerator to create a dummy project for fetching the information
# https://azuredevopsdemogenerator.azurewebsites.net/
# ![Screenshot%202024-11-24%20215318.png](attachment:Screenshot%202024-11-24%20215318.png)

# %% [markdown]
# login in orgranization you want to clone the project in
# ![Screenshot%202024-11-24%20215344.png](attachment:Screenshot%202024-11-24%20215344.png)

# %% [markdown]
# ![Screenshot%202024-11-26%20221105.png](attachment:Screenshot%202024-11-26%20221105.png)

# %% [markdown]
# #### Configure the Project
# your project would be displayed in your devops organisation ready to be played with
# ![Screenshot%202024-11-26%20221153.png](attachment:Screenshot%202024-11-26%20221153.png)

# %% [markdown]
# in the general setting of your new project you can change the working days , sprint cycle , workitems the project team members can use and also the edit teams and assign task specifically
# ![Screenshot%202024-11-26%20221307.png](attachment:Screenshot%202024-11-26%20221307.png)

# %% [markdown]
# ![Screenshot%202024-11-26%20221345.png](attachment:Screenshot%202024-11-26%20221345.png)

# %% [markdown]
# ![Screenshot%202024-11-26%20221523.png](attachment:Screenshot%202024-11-26%20221523.png)

# %% [markdown]
# #### Work items available
# here you can see all the workitems available in their full glory
# ![Screenshot%202024-11-26%20221556.png](attachment:Screenshot%202024-11-26%20221556.png)

# %% [markdown]
# #### Creating a epic titled 'product training' under wich a feature will come
# ![Screenshot%202024-11-26%20222433.png](attachment:Screenshot%202024-11-26%20222433.png)

# %% [markdown]
# #### Selecting work items/
# for time being we are going to select Feature work item , pretending that we are or have to add new feature in our website and want to maintain track of it using the Azure Scrum boards ' feature '
# ![Screenshot%202024-11-26%20223443.png](attachment:Screenshot%202024-11-26%20223443.png)

# %% [markdown]
# now in this feature we can create some backlogs stating what needs to be done , and change its status respectively![Screenshot%202024-11-26%20223226.png](attachment:Screenshot%202024-11-26%20223226.png)

# %% [markdown]
# ![Screenshot%202024-11-26%20223443.png](attachment:Screenshot%202024-11-26%20223443.png)

# %% [markdown]
# under every backlog you can add a task and monitor it more closely
# ![Screenshot%202024-11-26%20234043.png](attachment:Screenshot%202024-11-26%20234043.png)

# %% [markdown]
# you can use filters to find a specefic task assigned to someone
# ![Screenshot%202024-11-26%20234253.png](attachment:Screenshot%202024-11-26%20234253.png)

# %% [markdown]
# in the sprints section you can monitor every team sprint wise weather the task in being completed or not ![Screenshot%202024-11-26%20234546.png](attachment:Screenshot%202024-11-26%20234546.png)

# %% [markdown]
# you can also see the amount of work hour pending in the right most corner
# ![Screenshot%202024-11-26%20235216.png](attachment:Screenshot%202024-11-26%20235216.png)

# %% [markdown]
# #### Create a Dashboard
# from the accumulated information now we can create a dashboard for visualizing with different widgets suiting ![Screenshot%202024-11-27%20000207.png](attachment:Screenshot%202024-11-27%20000207.png)

# %% [markdown]
# ![Screenshot%202024-11-27%20000215.png](attachment:Screenshot%202024-11-27%20000215.png)

# %% [markdown]
# ![Screenshot%202024-11-27%20000339.png](attachment:Screenshot%202024-11-27%20000339.png)

# %% [markdown]
# #### More on Work Items in Azure Scrum Boards
#
# ##### User Stories:
#
# Represents a small piece of functionality from an end user's perspective.
#
# ##### Tasks:
#
# Breakdown of user stories into smaller, manageable tasks.
#
# ##### Bugs:
#
# Represents defects or issues identified during development or testing.
#
# ##### Epics:
#
# Larger bodies of work that can be broken down into multiple user stories.
#
# ##### Features:
#
# Represents a functional group of user stories or a larger piece of work.
#
# ##### Product Backlog:
#
# A prioritized list of all work items that must be addressed in the project - All the To-dos.
#
# ##### Sprint Backlog:
#
# Subset of the product backlog that the Development Team commits to completing during a specific sprint - ALL the Sprint To-dos.
#
# ##### Impediments:
#
# Obstacles or issues that hinder the progress of the team.
#
# ##### Test Cases:
#
# Specifies conditions to validate that a particular aspect of the system works correctly.
